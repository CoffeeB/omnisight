# %% [markdown]
# # OmniSight: Quantitative Benchmark Analysis & Calibration Curves
# Analyzes Experiment 01–05 empirical results and visualizes Expected Calibration Error (ECE) reliability diagrams.

# %%
# %matplotlib inline
import os
import sys
sys.path.insert(0, os.path.abspath(".."))
import json
import numpy as np
import matplotlib.pyplot as plt
from src.visualization.reliability_plots import plot_reliability_diagram, plot_degradation_profile

# Load experiment results if generated
with open("results_benchmark/benchmark_summary.json", "r") as f:
    results = json.load(f)

print("Loaded Benchmark Results:", list(results.keys()))
